# %% [markdown]
# ## Working with SQL

# %%
# !pip install mysql.connector
# Out:
# ...
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.1/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.1/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.1/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.1/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.1/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.1/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.1/11.9 MB ? eta -:--:--
#      --------------------------------------- 0.1/11.9 MB 276.8 kB/s eta 0:00:43
#      --------------------------------------- 0.1/11.9 MB 276.8 kB/s eta 0:00:43
# ...

# %%
import mysql.connector
import pandas as pd

# %%
conn = mysql.connector.Connect(host='localhost', user='root', password='', database='world')

# %%
pd.read_sql_query("SELECT * FROM city", conn)
# Out:
# C:\Users\Arbaz Khan\AppData\Local\Temp\ipykernel_23908\1432342221.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM city", conn)
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# ...

# %%
df = pd.read_sql_query("SELECT * FROM city WHERE CountryCode LIKE 'USA'", conn)
# Out:
# C:\Users\Arbaz Khan\AppData\Local\Temp\ipykernel_23908\4260220707.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("SELECT * FROM city WHERE CountryCode LIKE 'USA'", conn)

# %%
df
# Out:
#        ID          Name CountryCode        District  Population
# 0    3793      New York         USA        New York     8008278
# 1    3794   Los Angeles         USA      California     3694820
# 2    3795       Chicago         USA        Illinois     2896016
# 3    3796       Houston         USA           Texas     1953631
# 4    3797  Philadelphia         USA    Pennsylvania     1517550
# ..    ...           ...         ...             ...         ...
# 269  4062       Kenosha         USA       Wisconsin       89447
# 270  4063         Elgin         USA        Illinois       89408
# 271  4064        Odessa         USA           Texas       89293
# 272  4065        Carson         USA      California       89089
# 273  4066    Charleston         USA  South Carolina       89063
#
# [274 rows x 5 columns]

# %%
import pymysql
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 import pymysql
#
# ModuleNotFoundError: No module named 'pymysql'

# %%
# !pip install pymysql
# Out:
# ...
#    ---------------------------------------- 0.0/44.8 kB ? eta -:--:--
#    --------- ------------------------------ 10.2/44.8 kB ? eta -:--:--
#    ------------------ --------------------- 20.5/44.8 kB 131.3 kB/s eta 0:00:01
#    ------------------ --------------------- 20.5/44.8 kB 131.3 kB/s eta 0:00:01
#    ---------------------------------------- 44.8/44.8 kB 183.7 kB/s eta 0:00:00
# ...

# %%
import pymysql

from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://root:@localhost/world")

df = pd.read_sql_query("SELECT * FROM city WHERE CountryCode LIKE 'USA'", con=engine)

df

# %%
result = engine.excute("SELECT * FROM city WHERE CountryCode LIKE 'USA'")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 result = engine.excute("SELECT * FROM city WHERE CountryCode LIKE 'USA'")
#
# AttributeError: 'Engine' object has no attribute 'excute'
