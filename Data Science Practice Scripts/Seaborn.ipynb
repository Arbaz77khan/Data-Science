# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt
import plotly.express as px

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## Scatter plot

# %%
# Scatter plot -> axes level function
sns.scatterplot(data=tips, x='total_bill', y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#  relplot -> figure level function.
sns.relplot(data=tips, x='total_bill', y='tip', kind='scatter')

# %%
# additional parameters
sns.relplot(data=tips, x='total_bill', y='tip', kind='scatter', hue='sex', style='time', size='size')

# %%
# Facet plot -> multiple graphs inside figure using 'col','row'
sns.relplot(data=tips, x='total_bill', y='tip', kind='scatter', col='sex', row='time')

# %%
gap = px.data.gapminder()
gap
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
temp = gap[gap['country']=='India']
tempdf = gap[gap['country'].isin(['India', 'Germany', 'Zimbabwe'])]

# %%
temp
# Out:
#     country continent  year  lifeExp         pop    gdpPercap iso_alpha  \
# 696   India      Asia  1952   37.373   372000000   546.565749       IND
# 697   India      Asia  1957   40.249   409000000   590.061996       IND
# 698   India      Asia  1962   43.605   454000000   658.347151       IND
# 699   India      Asia  1967   47.193   506000000   700.770611       IND
# 700   India      Asia  1972   50.651   567000000   724.032527       IND
# 701   India      Asia  1977   54.208   634000000   813.337323       IND
# 702   India      Asia  1982   56.596   708000000   855.723538       IND
# 703   India      Asia  1987   58.553   788000000   976.512676       IND
# 704   India      Asia  1992   60.223   872000000  1164.406809       IND
# 705   India      Asia  1997   61.765   959000000  1458.817442       IND
# 706   India      Asia  2002   62.879  1034172547  1746.769454       IND
# 707   India      Asia  2007   64.698  1110396331  2452.210407       IND
#
#      iso_num
# 696      356
# ...

# %%
# Axes level
sns.lineplot(data=temp, x='year', y='lifeExp')
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
# figure level
sns.relplot(data=temp, x='year', y='lifeExp', kind='line')

# %%
tempdf
# Out:
#        country continent  year  lifeExp         pop     gdpPercap iso_alpha  \
# 564    Germany    Europe  1952   67.500    69145952   7144.114393       DEU
# 565    Germany    Europe  1957   69.100    71019069  10187.826650       DEU
# 566    Germany    Europe  1962   70.300    73739117  12902.462910       DEU
# 567    Germany    Europe  1967   70.800    76368453  14745.625610       DEU
# 568    Germany    Europe  1972   71.000    78717088  18016.180270       DEU
# 569    Germany    Europe  1977   72.500    78160773  20512.921230       DEU
# 570    Germany    Europe  1982   73.800    78335266  22031.532740       DEU
# 571    Germany    Europe  1987   74.847    77718298  24639.185660       DEU
# 572    Germany    Europe  1992   76.070    80597764  26505.303170       DEU
# 573    Germany    Europe  1997   77.340    82011073  27788.884160       DEU
# 574    Germany    Europe  2002   78.670    82350671  30035.801980       DEU
# ...

# %%
# multi line graph
sns.relplot(data=tempdf, x='year', y='lifeExp', kind='line', hue='country', style='continent')

# %%
# Axes level
sns.histplot(data=tips, x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
# figure level
sns.displot(data=tips, x='total_bill', kind='hist')

# %%
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# faceting using col and row -> not work on histplot function
sns.displot(data=tips, x='tip', kind='hist',col='sex',element='step')

# %%
# strip plot
# axes level function
sns.stripplot(data=tips,x='day',y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# using catplot
# figure level function
sns.catplot(data=tips, x='day',y='total_bill',kind='strip')

# %%
# jitter
sns.catplot(data=tips, x='day',y='total_bill',kind='strip',jitter=0.2,hue='sex')

# %%
# swarmplot
sns.catplot(data=tips, x='day',y='total_bill',kind='swarm')

# %%
sns.swarmplot(data=tips, x='day',y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# hue
sns.swarmplot(data=tips, x='day',y='total_bill',hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# Box plot
sns.boxplot(data=tips,x='day',y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# Using catplot
sns.catplot(data=tips,x='day',y='total_bill',kind='box')

# %%
# hue
sns.boxplot(data=tips,x='day',y='total_bill',hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# single boxplot -> numerical col
sns.boxplot(data=tips,x='total_bill')
# Out:
# <Axes: xlabel='total_bill'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Set the style and context of seaborn
sns.set(style="whitegrid")

# Increase the scale of the plot
sns.set(rc={'figure.figsize':(10,6)})

# Create the boxplot with more points on the y-axis
sns.boxplot(data=tips, y='total_bill')
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.boxplot(data=tips, y='total_bill')

# Set the ticks on the y-axis
plt.yticks(range(5, 26, 5))  # This will set ticks from 5 to 25 in steps of 5

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 4
#       1 sns.boxplot(data=tips, y='total_bill')
#       3 # Set the ticks on the y-axis
# ----> 4 plt.yticks(range(5, 26, 5))  # This will set ticks from 5 to 25 in steps of 5
#       6 # Show the plot
#       7 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\_api\__init__.py:217, in caching_module_getattr.<locals>.__getattr__(name)
#     215 if name in props:
#     216     return props[name].__get__(instance)
# --> 217 raise AttributeError(
#     218     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'yticks'

# %%
sns.boxplot(data=tips, y='total_bill')

# Get the current Axes object
ax = plt.gca()

# Set the ticks on the y-axis
ax.set_yticks(range(5, 26, 5))  # This will set ticks from 5 to 25 in steps of 5

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 4
#       1 sns.boxplot(data=tips, y='total_bill')
#       3 # Get the current Axes object
# ----> 4 ax = plt.gca()
#       6 # Set the ticks on the y-axis
#       7 ax.set_yticks(range(5, 26, 5))  # This will set ticks from 5 to 25 in steps of 5
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\_api\__init__.py:217, in caching_module_getattr.<locals>.__getattr__(name)
#     215 if name in props:
#     216     return props[name].__get__(instance)
# --> 217 raise AttributeError(
#     218     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'gca'

# %%
ax = sns.catplot(data=tips, x='total_bill', kind='box')

# Set the ticks on the y-axis
ax.set_xticks(range(1, 56, 1))  # This will set ticks from 5 to 55 in steps of 5

# Show the plot
ax
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 4
#       1 ax = sns.catplot(data=tips, x='total_bill', kind='box')
#       3 # Set the ticks on the y-axis
# ----> 4 ax.set_xticks(range(1, 56, 1))  # This will set ticks from 5 to 55 in steps of 5
#       6 # Show the plot
#       7 ax
#
# AttributeError: 'FacetGrid' object has no attribute 'set_xticks'

# %%
sns.catplot(data=tips,x='day',y='total_bill',kind='violin',hue='sex',split=True)

# %%
sns.catplot(data=tips,x='day',y='total_bill',kind='violin',hue='sex')

# %%
sns.catplot(data=tips,x='day',y='total_bill',kind='violin')
